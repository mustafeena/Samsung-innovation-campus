# %% [markdown]
# <a href="https://colab.research.google.com/github/mustafeena/Samsung-innovation-campus/blob/main/ex_0202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Coding Exercise #0202

# %% [markdown]
# ### 1. NumPy array operations:

# %% [markdown]
# #### 1.1. '+' and '*' operators for Python lists:

# %%
import numpy as np

# %%
a = [1, 2, 3]

# %%
a + a

# %%
a*3

# %%
b = np.array([1, 2, 3])

# %%
b*3

# %%
b + b

# %%
np.repeat(b, 3)

# %% [markdown]
# #### 1.2. '+' and '*' operators for NumPy arrays:

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

# %%
a+b

# %%
a-b

# %%
a*b

# %%
1.0*a/b

# %% [markdown]
# #### 1.3. Universal functions:

# %%
x = np.array([0, 1, 2, 3, 4, 5])

# %%
np.sqrt(x)

# %%
np.exp(x)

# %%
type(np.sqrt)

# %%
type(np.exp)

# %% [markdown]
# #### 1.4. NumPy functions:

# %%
np.random.seed(123)
a = np.random.randint(1, 11, size=1000)

# %%
np.unique(a)

# %%
np.median(a)

# %%
np.sum(a)

# %%
np.round(np.var(a),2)

# %%
np.round(np.mean(a),2)

# %%
np.round(np.std(a),2)

# %%
np.max(a)

# %%
np.min(a)

# %% [markdown]
# #### 1.5. Statistical methods of NumPy arrays:

# %%
x=np.arange(1,11)

# %%
x.sum()

# %%
x.mean()

# %%
x.std()

# %%
x.var()

# %%
x.cumsum()

# %%
y = np.arange(1,10)
y = y.reshape((3,-1))
print(y)

# %%
print(y.mean(axis=0))

# %%
print(y.mean(axis=1))

# %%
z = np.random.randint(10,size=1000)

# %%
z.max()

# %%
z.min()

# %%
(z > 5).sum()

# %%
np.unique(z)

# %%
sorted(set(z))

# %%
a = np.array([2,-3,4,5,7,0,1,-1])

# %%
a.argmax()

# %%
a.argmin()
