# %% [markdown]
# <a href="https://colab.research.google.com/github/mustafeena/Samsung-innovation-campus/blob/main/ex_0603.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Coding Exercise #0603

# %%
import re

# %% [markdown]
# ### 1. Regular expressions (groups):

# %% [markdown]
# #### 1.1. Some examples of group:

# %%
reg_ex = re.compile("([0-9]+)")
m = reg_ex.search("I am 22 years old. She is 20 years old.")
print(m.group(1))
# Out:
# 22

# %%
reg_ex = re.compile("([0-9]+)[^0-9]+([0-9]+)")
m = reg_ex.search("I am 22 years old. She is 20 years old.")
print(m.group(1))
print(m.group(2))
# Out:
# 22
# 20

# %%
reg_ex = re.compile("([^0-9]+)([0-9]+)[^0-9]+([0-9]+)[^0-9]+([0-9]+)")
m = reg_ex.search("John Wheeler 010-1234-5678")
print((m.group(1)).strip())
print(m.group(2))
print(m.group(3))
print(m.group(4))
# Out:
# John Wheeler
# 010
# 1234
# 5678

# %% [markdown]
# #### 1.2. Some exaples of group with shorthand expression:
# \d   =   [0-9]  <br>
# \D    =  [^0-9]  <br>
# \w   =   [0-9a-zA-Z_]  <br>
# \W    =  [^0-9a-zA-Z_]  <br>

# %%
reg_ex = re.compile("(\d+)")
m = reg_ex.search("I am 22 years old. She is 20 years old.")
print(m.group(1))
# Out:
# 22

# %%
reg_ex = re.compile("(\d+)\D+(\d+)")
m = reg_ex.search("I am 22 years old. She is 20 years old.")
print(m.group(1))
print(m.group(2))
# Out:
# 22
# 20

# %%
reg_ex = re.compile("(\D+)(\d+)\D+(\d+)\D+(\d+)")
m = reg_ex.search("John Wheeler 010-1234-5678")
print((m.group(1)).strip())
print(m.group(2))
print(m.group(3))
print(m.group(4))
# Out:
# John Wheeler
# 010
# 1234
# 5678

# %%
# Hide the phone number.
reg_ex = re.compile("(\D+)(\d+)\D+(\d+)\D+(\d+)")
m = reg_ex.search("John Wheeler 010-1234-5678")
print((m.group(1)).strip() + " " + m.group(2) + "-****-****")
# Out:
# John Wheeler 010-****-****

# %%
# Extract only the phone number.
reg_ex = re.compile("(\D+)((\d+)\D+(\d+)\D+(\d+))")
m = reg_ex.search("John Wheeler 010-1234-5678")
print("PHONE : " + m.group(2))
# Out:
# PHONE : 010-1234-5678
