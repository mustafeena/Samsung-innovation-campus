# %% [markdown]
# <a href="https://colab.research.google.com/github/mustafeena/Samsung-innovation-campus/blob/main/ex_0203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Coding Exercise #0203

# %% [markdown]
# ### 1. Doing linear algebra with NumPy arrays:

# %%
import numpy as np

# %% [markdown]
# #### 1.1. Vectors:

# %%
x = np.array([1, 3, 5])
y = np.array([2, 4, 6])

# %%
x + y

# %%
x - y

# %% [markdown]
# The following operations are possible in NumPy but not in linear algebra:

# %%
x * y

# %%
x / y

# %% [markdown]
# Internal product with dot():

# %%
np.dot(x,y)

# %%
x.dot(y)

# %%
y.dot(x)

# %%
np.sum(x*y)

# %% [markdown]
# #### 1.2. Creating matrices:

# %%
np.zeros((2,3))

# %%
np.ones((2,3))

# %%
np.random.seed(222)
np.random.random((2,2))

# %%
np.random.seed(111)
np.random.randn(2,2)

# %%
np.diag([1,2,3])

# %% [markdown]
# #### 1.3. Matrix operations:

# %% [markdown]
# Matrix addition, subtraction and multiplication:

# %%
m1 = np.array([[1, 2, 3],[4, 5, 6]])
m2 = np.array([[6, 5, 4],[3, 2, 1]])

# %%
m1 + m2

# %%
m1 - m2

# %%
np.transpose(m2)

# %% [markdown]
# Matrix multiplication with dot():

# %%
np.dot(m1,np.transpose(m2))

# %%
x = np.array([1, 3, 5])
y = np.array([2, 4, 6])
x = x.reshape((3,1))
y = y.reshape((1,3))
print("{}".format(x))
print(" ----------")
print("{}".format(y))

# %%
y.dot(x)[0,0]

# %%
x.dot(y)

# %% [markdown]
# The following operations are possible in NumPy but not in linear algebra:

# %%
m1 * m2

# %%
m1 / m2

# %% [markdown]
# Operations involving matrix and scalar:

# %%
m = np.array([[1, 2],[3, 4]])

# %%
m*3

# %%
m/2

# %% [markdown]
# #### 1.4. Inverse matrix and system of linear equations:

# %% [markdown]
# Calculating the inverse matrix:

# %%
m = np.array([[1, 2],[3, 4]])
minv = np.linalg.inv(m)
minv

# %%
mres = np.dot(m, minv)
np.round(mres,2)

# %% [markdown]
# System of linear equations (number of equations = number of unknowns):

# %%
A = np.array([[5, 8],[6, 4]])
b = np.array([[30], [25]])
Ainv = np.linalg.inv(A)
print(np.dot(Ainv,b))

# %%
np.linalg.solve(A, b)
